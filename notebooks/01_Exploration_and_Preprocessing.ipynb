# %%
import pandas as pd
import sys
import os

sys.path.append(os.path.abspath(os.path.join('..')))

from src.preprocess import clean_text

pd.set_option('display.max_colwidth', None)

# %%
# Load the raw dataset
df = pd.read_csv('../data/raw/labeled_data.csv')

# Quick look at the raw data
print(f"Dataset Shape: {df.shape}")
df[['tweet', 'class']].head()
# Out:
# Dataset Shape: (24783, 7)
#                                                                                                                                           tweet  \
# 0  !!! RT @mayasolovely: As a woman you shouldn't complain about cleaning up your house. &amp; as a man you should always take the trash out...
# 1                                                         !!!!! RT @mleew17: boy dats cold...tyga dwn bad for cuffin dat hoe in the 1st place!!
# 2                      !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby4life: You ever fuck a bitch and she start to cry? You be confused as shit
# 3                                                                                !!!!!!!!! RT @C_G_Anderson: @viva_based she look like a tranny
# 4     !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you hear about me might be true or it might be faker than the bitch who told it to ya &#57361;
#
#    class
# 0      2
# 1      1
# 2      1
# 3      1
# 4      1

# %%
# Create a new column for the cleaned text
df['cleaned_tweet'] = df['tweet'].apply(clean_text)

# Select a few random samples to compare
sample_df = df[['tweet', 'cleaned_tweet']].sample(5, random_state=42)

# Display the comparison
sample_df
# Out:
#                                                                                                                                     tweet  \
# 2281                                                                                          934 8616\ni got a missed call from yo bitch
# 15914                                                       RT @KINGTUNCHI_: Fucking with a bad bitch you gone need some money lil homie!
# 18943  RT @eanahS__: @1inkkofrosess lol my credit ain't no where near good , but I know the right man for the job .. that ho nice though!
# 16407                              RT @Maxin_Betha Wipe the cum out of them faggot RT @80sbaby4life Contact lens is wildin can't see shit
# 13326                            Niggas cheat on they bitch and don't expect no pay back WHATSOEVER. Yall just as naive as these bitches.
#
#                                                                              cleaned_tweet
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# count plot
plt.figure(figsize=(6,4))
sns.countplot(x='class', data=df)
plt.title('Distribution of Classes (0=Hate, 1=Offensive, 2=Neither)')
plt.show()
